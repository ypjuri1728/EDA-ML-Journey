# %% [markdown]
# <a href="https://colab.research.google.com/github/ypjuri1728/EDA-ML-Journey/blob/main/Titanic_EDA_Day01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.nunique()
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %% [markdown]
# whatever we use this valuecount for the understand what columns actually contains.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# asking: Are there duplicates rows in my dataset?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df[df["Fare"] > 100][["PassengerId", "Pclass", "Fare"]]
# Out:
#      PassengerId  Pclass      Fare
# 24           916       1  262.3750
# 53           945       1  263.0000
# 59           951       1  262.3750
# 64           956       1  262.3750
# 69           961       1  263.0000
# 74           966       1  211.5000
# 75           967       1  211.5000
# 81           973       1  221.7792
# 114         1006       1  221.7792
# 141         1033       1  151.5500
# 142         1034       1  262.3750
# 156         1048       1  221.7792
# 184         1076       1  247.5208
# 196         1088       1  134.5000
# 202         1094       1  227.5250
# 217         1109       1  164.8667
# 218         1110       1  211.5000
# 239         1131       1  106.4250
# 242         1134       1  134.5000
# 252         1144       1  136.7792
# 272         1164       1  136.7792
# 306         1198       1  151.5500
# 314         1206       1  135.6333
# 316         1208       1  146.5208
# 324         1216       1  211.3375
# 343         1235       1  512.3292
# ...

# %%
df.groupby("Pclass")["Fare"].agg(["count", "mean", "median", "min", "max"])
# Out:
#         count       mean   median     min       max
# Pclass
# 1         107  94.280297  60.0000  0.0000  512.3292
# 2          93  22.202104  15.7500  9.6875   73.5000
# 3         217  12.459678   7.8958  3.1708   69.5500

# %%
df[(df["Pclass"] == 1) & (df["Fare"] == df["Fare"].max())]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 343      1  PC 17755  512.3292  B51 B53 B55        C

# %% [markdown]
# Pclass 1 -> higher fares
#
# Pclass 2 -> medium fares
#
# Pclass 3 -> lower fares

# %% [markdown]
# The highest fare belongs to a first-class passenger, so the extreme fare appears to be associated with passenger class rather than automatically being an invalid value.

# %%
df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.467290
# 2    0.322581
# 3    0.330275
# Name: Survived, dtype: float64

# %%
df[df["Pclass"] == 1][["PassengerId", "Pclass", "Fare"]].sort_values("Fare", ascending=False).head(10)
# Out:
#      PassengerId  Pclass      Fare
# 343         1235       1  512.3292
# 69           961       1  263.0000
# 53           945       1  263.0000
# 59           951       1  262.3750
# 64           956       1  262.3750
# 142         1034       1  262.3750
# 24           916       1  262.3750
# 375         1267       1  262.3750
# 184         1076       1  247.5208
# 202         1094       1  227.5250

# %%
df[df["Fare"] > 200][
    ["PassengerId", "Name", "Sex", "Age", "Pclass", "Fare", "Ticket", "Cabin", "SibSp", "Parch"]
]
# Out:
#      PassengerId                                               Name     Sex  \
# 24           916    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female
# 53           945                         Fortune, Miss. Ethel Flora  female
# 59           951                        Chaudanson, Miss. Victorine  female
# 64           956                        Ryerson, Master. John Borie    male
# 69           961                Fortune, Mrs. Mark (Mary McDougald)  female
# 74           966                               Geiger, Miss. Amalie  female
# 75           967                                 Keeping, Mr. Edwin    male
# 81           973                                 Straus, Mr. Isidor    male
# 114         1006             Straus, Mrs. Isidor (Rosalie Ida Blun)  female
# 142         1034                         Ryerson, Mr. Arthur Larned    male
# 156         1048                                  Bird, Miss. Ellen  female
# ...

# %% [markdown]
# The Fare is likely related to the booking/ticket, not simply an individual passenger.

# %% [markdown]
# 512.3292 is still unusually high, but we now have evidence that high fares can be legitimate ticket-level values.

# %%
df[df["Ticket"] == "PC 17755"]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 343      1  PC 17755  512.3292  B51 B53 B55        C

# %% [markdown]
# **Investigation: Checked high-fare passengers, compared fares by Pclass, and examined ticket patterns.**

# %% [markdown]
# *Insight: High fares are strongly associated with first-class passengers. Several other first-class passengers also have fares above 200, suggesting that high fares can be legitimate. The 512.3292 ticket appears only once in this dataset, so its exact pricing reason cannot be determined from the available columns.*
#
# Decision: Keep the value; don't delete it without evidence that it is an error.
